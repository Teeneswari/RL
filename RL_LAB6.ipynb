# %% [markdown]
# <a href="https://colab.research.google.com/github/Teeneswari/RL/blob/main/RL_LAB6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q gymnasium

import gymnasium as gym
import numpy as np

NUM_EPISODES = 5


def random_agent(env_name):

    print("\n" + "=" * 60)
    print("Environment:", env_name)
    print("=" * 60)

    # Create environment
    env = gym.make(env_name)

    rewards = []

    for episode in range(1, NUM_EPISODES + 1):

        # Reset environment
        state, info = env.reset()

        total_reward = 0
        steps = 0

        while True:

            # Select random action
            action = env.action_space.sample()

            # Execute action
            next_state, reward, terminated, truncated, info = env.step(action)

            # Observe next state and reward
            state = next_state
            total_reward += reward
            steps += 1

            # Check whether episode has terminated
            if terminated or truncated:
                break

        rewards.append(total_reward)

        # Display result for each episode
        print(f"Episode {episode}: Total Reward = {total_reward}")
        print(f"Steps = {steps}")

    # Calculate average reward
    average_reward = np.mean(rewards)

    print("\nTotal Rewards:", rewards)
    print("Average Reward:", round(average_reward, 2))

    env.close()


# --------------------------------------------------
# 1. CLIFF WALKING
# --------------------------------------------------
random_agent("CliffWalking-v1")


# --------------------------------------------------
# 2. TAXI
# --------------------------------------------------
random_agent("Taxi-v4")
# Out:
# ============================================================
# Environment: CliffWalking-v1
# ============================================================
# Episode 1: Total Reward = -29838
# Steps = 3306
# Episode 2: Total Reward = -9198
# Steps = 1080
# Episode 3: Total Reward = -85611
# Steps = 8292
# Episode 4: Total Reward = -70132
# Steps = 6475
# Episode 5: Total Reward = -20469
# Steps = 1956
#
# Total Rewards: [-29838, -9198, -85611, -70132, -20469]
# Average Reward: -43049.6
#
# ============================================================
# Environment: Taxi-v4
# ============================================================
# Episode 1: Total Reward = -803
# Steps = 200
# Episode 2: Total Reward = -749
# Steps = 200
# Episode 3: Total Reward = -875
# Steps = 200
# Episode 4: Total Reward = -731
# Steps = 200
# Episode 5: Total Reward = -785
# Steps = 200
#
# Total Rewards: [-803, -749, -875, -731, -785]
# Average Reward: -788.6
