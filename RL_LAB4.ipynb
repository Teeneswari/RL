# %% [markdown]
# <a href="https://colab.research.google.com/github/Teeneswari/RL/blob/main/RL_LAB4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import pandas as pd

# %%
machines = ['A', 'B', 'C']

M = 3
N_play = 10

N = {'A': 0, 'B': 0, 'C': 0}

R = {'A': 0, 'B': 0, 'C': 0}

Q = {'A': 0.0, 'B': 0.0, 'C': 0.0}

UCB = {'A': float('inf'), 'B': float('inf'), 'C': float('inf')}

# %%
reward_patterns = {
    'A': [3, 4, 2, 5],
    'B': [6, 7, 5, 8],
    'C': [4, 3, 5, 4]
}

reward_index = {
    'A': 0,
    'B': 0,
    'C': 0
}

# %%
results = []

# %%
for play in range(1, N_play + 1):

    # Calculate UCB before selecting machine
    for machine in machines:

        if N[machine] == 0:
            UCB[machine] = float('inf')

        else:
            UCB[machine] = (
                Q[machine]
                + math.sqrt(
                    (2 * math.log(play)) / N[machine]
                )
            )

    # Select machine with highest UCB
    selected_machine = max(UCB, key=UCB.get)

    # Reward collection
    index = reward_index[selected_machine]

    # Cycle through the given reward pattern
    reward = reward_patterns[selected_machine][index % 4]

    reward_index[selected_machine] += 1

    # Update N, R and Q
    old_Q = Q[selected_machine]

    N[selected_machine] += 1

    R[selected_machine] += reward

    Q[selected_machine] = (
        old_Q
        + (reward - old_Q) / N[selected_machine]
    )

    # Display calculation for first two plays
    if play <= 2:

        print("\n========================================")
        print("CALCULATION FOR PLAY", play)
        print("========================================")

        print("Selected Machine =", selected_machine)
        print("Reward =", reward)

        print(
            "Q_new = Q_old + (Reward - Q_old) / N"
        )

        print(
            f"Q_new = {old_Q:.2f} + "
            f"({reward} - {old_Q:.2f}) / "
            f"{N[selected_machine]}"
        )

        print(
            f"Q_new = {Q[selected_machine]:.4f}"
        )

    # Calculate UCB after update
    for machine in machines:

        if N[machine] == 0:
            UCB[machine] = float('inf')

        else:
            UCB[machine] = (
                Q[machine]
                + math.sqrt(
                    (2 * math.log(play)) / N[machine]
                )
            )

    # Store play result
    results.append({
        'Play': play,
        'Machine': selected_machine,
        'Reward': reward,

        'N(A)': N['A'],
        'N(B)': N['B'],
        'N(C)': N['C'],

        'R(A)': R['A'],
        'R(B)': R['B'],
        'R(C)': R['C'],

        'UCB(A)': (
            'inf' if math.isinf(UCB['A'])
            else round(UCB['A'], 4)
        ),

        'UCB(B)': (
            'inf' if math.isinf(UCB['B'])
            else round(UCB['B'], 4)
        ),

        'UCB(C)': (
            'inf' if math.isinf(UCB['C'])
            else round(UCB['C'], 4)
        ),

        'Q(A)': round(Q['A'], 4),
        'Q(B)': round(Q['B'], 4),
        'Q(C)': round(Q['C'], 4)
    })
# Out:
# ========================================
# CALCULATION FOR PLAY 1
# ========================================
# Selected Machine = A
# Reward = 3
# Q_new = Q_old + (Reward - Q_old) / N
# Q_new = 0.00 + (3 - 0.00) / 1
# Q_new = 3.0000
#
# ========================================
# CALCULATION FOR PLAY 2
# ========================================
# Selected Machine = B
# Reward = 6
# Q_new = Q_old + (Reward - Q_old) / N
# Q_new = 0.00 + (6 - 0.00) / 1
# Q_new = 6.0000

# %%
df = pd.DataFrame(results)

print("\n========================================")
print("PLAY-BY-PLAY RESULTS")
print("========================================")

print(df.to_string(index=False))
# Out:
# ========================================
# PLAY-BY-PLAY RESULTS
# ========================================
#  Play Machine  Reward  N(A)  N(B)  N(C)  R(A)  R(B)  R(C)  UCB(A)  UCB(B)  UCB(C)  Q(A)   Q(B)  Q(C)
#     1       A       3     1     0     0     3     0     0  3.0000     inf     inf   3.0 0.0000   0.0
#     2       B       6     1     1     0     3     6     0  4.1774  7.1774     inf   3.0 6.0000   0.0
#     3       C       4     1     1     1     3     6     4  4.4823  7.4823  5.4823   3.0 6.0000   4.0
#     4       B       7     1     2     1     3    13     4  4.6651  7.6774  5.6651   3.0 6.5000   4.0
#     5       B       5     1     3     1     3    18     4  4.7941  7.0358  5.7941   3.0 6.0000   4.0
#     6       B       8     1     4     1     3    26     4  4.8930  7.4465   5.893   3.0 6.5000   4.0
#     7       B       6     1     5     1     3    32     4  4.9728  7.2822  5.9728   3.0 6.4000   4.0
#     8       B       7     1     6     1     3    39     4  5.0393  7.3326  6.0393   3.0 6.5000   4.0
#     9       B       5     1     7     1     3    44     4  5.0963   7.078  6.0963   3.0 6.2857   4.0
#    10       B       8     1     8     1     3    52     4  5.1460  7.2587   6.146   3.0 6.5000   4.0

# %%
print("\n========================================")
print("FINAL N TABLE - PARTICIPATION COUNT")
print("========================================")

N_table = pd.DataFrame({
    'Machine': machines,
    'N (Participation Count)': [
        N['A'],
        N['B'],
        N['C']
    ]
})

print(N_table.to_string(index=False))
# Out:
# ========================================
# FINAL N TABLE - PARTICIPATION COUNT
# ========================================
# Machine  N (Participation Count)
#       A                        1
#       B                        8
#       C                        1

# %%
print("\n========================================")
print("FINAL R TABLE - TOTAL REWARD")
print("========================================")

R_table = pd.DataFrame({
    'Machine': machines,
    'R (Total Reward)': [
        R['A'],
        R['B'],
        R['C']
    ]
})

print(R_table.to_string(index=False))
# Out:
# ========================================
# FINAL R TABLE - TOTAL REWARD
# ========================================
# Machine  R (Total Reward)
#       A                 3
#       B                52
#       C                 4

# %%
print("\n========================================")
print("FINAL UCB TABLE")
print("========================================")

UCB_table = pd.DataFrame({
    'Machine': machines,
    'UCB': [
        'inf' if math.isinf(UCB['A']) else round(UCB['A'], 4),
        'inf' if math.isinf(UCB['B']) else round(UCB['B'], 4),
        'inf' if math.isinf(UCB['C']) else round(UCB['C'], 4)
    ]
})

print(UCB_table.to_string(index=False))
# Out:
# ========================================
# FINAL UCB TABLE
# ========================================
# Machine    UCB
#       A 5.1460
#       B 7.2587
#       C 6.1460

# %%
print("\n========================================")
print("FINAL Q TABLE - ESTIMATED REWARD")
print("========================================")

Q_table = pd.DataFrame({
    'Machine': machines,
    'Q (Estimated Reward)': [
        round(Q['A'], 4),
        round(Q['B'], 4),
        round(Q['C'], 4)
    ]
})

print(Q_table.to_string(index=False))
# Out:
# ========================================
# FINAL Q TABLE - ESTIMATED REWARD
# ========================================
# Machine  Q (Estimated Reward)
#       A                   3.0
#       B                   6.5
#       C                   4.0

# %%
total_reward = sum(R.values())

print("\n========================================")
print("TOTAL REWARD")
print("========================================")

print("Total Reward Received =", total_reward)
# Out:
# ========================================
# TOTAL REWARD
# ========================================
# Total Reward Received = 59

# %%
best_machine = max(Q, key=Q.get)

print("\n========================================")
print("BEST MACHINE")
print("========================================")

print("Machine with Highest Q-value =", best_machine)
print("Highest Q-value =", round(Q[best_machine], 4))
# Out:
# ========================================
# BEST MACHINE
# ========================================
# Machine with Highest Q-value = B
# Highest Q-value = 6.5
